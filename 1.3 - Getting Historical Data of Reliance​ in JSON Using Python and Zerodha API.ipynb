# %%
# https://unofficed.com/courses/mastering-algotrading-a-beginners-guide-using-kiteconnect-api/lessons/getting-historical-data-of-reliance-in-json-using-python-and-zerodha-api/

# %%
import logging
from kiteconnect import KiteConnect

logging.basicConfig(level=logging.DEBUG)

kite = KiteConnect(api_key="your_api_key")

# Redirect the user to the login url obtained
# from kite.login_url(), and receive the request_token
# from the registered redirect url after the login flow.
# Once you have the request_token, obtain the access_token
# as follows.

data = kite.generate_session("request_token_here", api_secret="your_secret")
kite.set_access_token(data["access_token"])
# Out:
# /tmp/ipykernel_4126809/1105643221.py:8: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   from kite.kitecustom import *

# %%
instrument_token = 738561

# %%
# Fetch historical data for RELIANCE
historical_data = kite.historical_data(instrument_token, '2023-01-01', '2023-09-01', interval='minute')
historical_data
# Out:
# ---------------------------------------------------------------------------
# InputException                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Fetch historical data for RELIANCE
# ----> 2 historical_data = kite.historical_data(instrument_token, '2023-01-01', '2023-09-01', interval='minute')
#       3 historical_data
#
# File ~/apps/zerodha/../kiteconnect/connect.py:503, in KiteConnect.historical_data(self, instrument_token, from_date, to_date, interval, continuous, oi)
#     500 from_date_string = from_date.strftime(date_string_format) if type(from_date) == datetime.datetime else from_date
#     501 to_date_string = to_date.strftime(date_string_format) if type(to_date) == datetime.datetime else to_date
# --> 503 data = self._get("market.historical", {
#     504     "instrument_token": instrument_token,
#     505     "from": from_date_string,
#     506     "to": to_date_string,
#     507     "interval": interval,
#     508     "continuous": 1 if continuous else 0,
#     509     "oi": 1 if oi else 0
#     510 })
#     512 return self._format_historical(data, oi)
#
# File ~/apps/zerodha/../kiteconnect/connect.py:601, in KiteConnect._get(self, route, params)
#     599 def _get(self, route, params=None):
#     600     """Alias for sending a GET request."""
# --> 601     return self._request(route, "GET", params)
#
# File ~/apps/zerodha/../kiteconnect/connect.py:671, in KiteConnect._request(self, route, method, parameters)
#     669         # native Kite errors
#     670         exp = getattr(ex, data["error_type"], ex.GeneralException)
# --> 671         raise exp(data["message"], code=r.status_code)
#     673     return data["data"]
#     674 elif "csv" in r.headers["content-type"]:
#
# InputException: interval exceeds max limit: 60 days

# %%
# Fetch historical data for RELIANCE
historical_data = kite.historical_data(instrument_token, '2023-01-01', '2023-09-01', interval='day')
historical_data
# Out:
# [{'date': datetime.datetime(2023, 1, 2, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2430.65,
#   'high': 2458.3,
#   'low': 2428.95,
#   'close': 2455.35,
#   'volume': 2573872},
#  {'date': datetime.datetime(2023, 1, 3, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2445,
#   'high': 2452.6,
#   'low': 2428.55,
#   'close': 2437.4,
#   'volume': 3708138},
#  {'date': datetime.datetime(2023, 1, 4, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2437.35,
#   'high': 2441.2,
#   'low': 2396.35,
#   'close': 2400.7,
#   'volume': 4485677},
#  {'date': datetime.datetime(2023, 1, 5, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2405.4,
#   'high': 2417.7,
#   'low': 2386.8,
#   'close': 2396.4,
#   'volume': 6602518},
#  {'date': datetime.datetime(2023, 1, 6, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2408.4,
#   'high': 2428.7,
#   'low': 2400.45,
#   'close': 2418.15,
#   'volume': 3074212},
#  {'date': datetime.datetime(2023, 1, 9, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2426.2,
#   'high': 2480.25,
#   'low': 2424.3,
#   'close': 2475.25,
#   'volume': 5191513},
#  {'date': datetime.datetime(2023, 1, 10, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2484.05,
#   'high': 2484.05,
#   'low': 2426.85,
#   'close': 2438.65,
#   'volume': 3896093},
#  {'date': datetime.datetime(2023, 1, 11, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2433.05,
#   'high': 2438.3,
#   'low': 2403.1,
#   'close': 2407.95,
#   'volume': 5572449},
#  {'date': datetime.datetime(2023, 1, 12, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2406.7,
#   'high': 2414,
#   'low': 2349.65,
#   'close': 2355.95,
#   'volume': 8564171},
#  {'date': datetime.datetime(2023, 1, 13, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2343.35,
#   'high': 2357.15,
#   'low': 2320.65,
#   'close': 2352.1,
#   'volume': 9982664},
#  {'date': datetime.datetime(2023, 1, 16, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2357,
#   'high': 2363.6,
#   'low': 2313.4,
#   'close': 2329.7,
#   'volume': 6596106},
#  {'date': datetime.datetime(2023, 1, 17, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2342.95,
#   'high': 2366.8,
#   'low': 2335.9,
#   'close': 2362.8,
#   'volume': 5205189},
#  {'date': datetime.datetime(2023, 1, 18, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2357.75,
#   'high': 2374.5,
#   'low': 2345.2,
#   'close': 2358.9,
#   'volume': 6511103},
#  {'date': datetime.datetime(2023, 1, 19, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2357.15,
#   'high': 2365.05,
#   'low': 2341.7,
#   'close': 2356.35,
#   'volume': 5780879},
#  {'date': datetime.datetime(2023, 1, 20, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2359.15,
#   'high': 2359.15,
#   'low': 2323.2,
#   'close': 2328.35,
#   'volume': 7228626},
#  {'date': datetime.datetime(2023, 1, 23, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2334.4,
#   'high': 2350.8,
#   'low': 2311.5,
#   'close': 2316.55,
#   'volume': 5303530},
#  {'date': datetime.datetime(2023, 1, 24, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2325.8,
#   'high': 2329.3,
#   'low': 2275.6,
#   'close': 2302.9,
#   'volume': 7983172},
#  {'date': datetime.datetime(2023, 1, 25, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2299.55,
#   'high': 2301.7,
#   'low': 2268.6,
#   'close': 2271.05,
#   'volume': 5996313},
#  {'date': datetime.datetime(2023, 1, 27, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2272.8,
#   'high': 2275.6,
#   'low': 2203.45,
#   'close': 2227.95,
#   'volume': 12506288},
#  {'date': datetime.datetime(2023, 1, 30, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2222.6,
#   'high': 2260.9,
#   'low': 2193.3,
#   'close': 2249.3,
#   'volume': 10541150},
#  {'date': datetime.datetime(2023, 1, 31, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2270.5,
#   'high': 2275.9,
#   'low': 2231.45,
#   'close': 2243.7,
#   'volume': 10986329},
#  {'date': datetime.datetime(2023, 2, 1, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2268.55,
#   'high': 2268.55,
#   'low': 2197.15,
#   'close': 2230.4,
#   'volume': 9367403},
#  {'date': datetime.datetime(2023, 2, 2, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2209.5,
#   'high': 2238.1,
#   'low': 2202.85,
#   'close': 2218.05,
#   'volume': 6614895},
#  {'date': datetime.datetime(2023, 2, 3, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2239.05,
#   'high': 2239.05,
#   'low': 2185.7,
#   'close': 2220,
#   'volume': 11958511},
#  {'date': datetime.datetime(2023, 2, 6, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2206.65,
#   'high': 2212.4,
#   'low': 2197.9,
#   'close': 2203.25,
#   'volume': 7183886},
#  {'date': datetime.datetime(2023, 2, 7, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2203.8,
#   'high': 2218.5,
#   'low': 2185.7,
#   'close': 2198,
#   'volume': 7327951},
#  {'date': datetime.datetime(2023, 2, 8, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2204.75,
#   'high': 2249.45,
#   'low': 2199.05,
#   'close': 2241.9,
#   'volume': 10244956},
#  {'date': datetime.datetime(2023, 2, 9, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2243.3,
#   'high': 2259.9,
#   'low': 2224.75,
#   'close': 2245.8,
#   'volume': 6377706},
#  {'date': datetime.datetime(2023, 2, 10, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2244.7,
#   'high': 2244.7,
#   'low': 2212.65,
#   'close': 2227.3,
#   'volume': 5224287},
#  {'date': datetime.datetime(2023, 2, 13, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2230.7,
#   'high': 2240,
#   'low': 2205.3,
#   'close': 2214.6,
#   'volume': 5012248},
#  {'date': datetime.datetime(2023, 2, 14, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2220.9,
#   'high': 2270.45,
#   'low': 2214.9,
#   'close': 2266.8,
#   'volume': 6934080},
#  {'date': datetime.datetime(2023, 2, 15, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2264.8,
#   'high': 2323.15,
#   'low': 2261.95,
#   'close': 2318.15,
#   'volume': 16221050},
#  {'date': datetime.datetime(2023, 2, 16, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2334.8,
#   'high': 2348.5,
#   'low': 2311.55,
#   'close': 2316.3,
#   'volume': 8358749},
#  {'date': datetime.datetime(2023, 2, 17, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2306.75,
#   'high': 2332.95,
#   'low': 2297.8,
#   'close': 2326,
#   'volume': 5717681},
#  {'date': datetime.datetime(2023, 2, 20, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2330.55,
#   'high': 2335.1,
#   'low': 2297.3,
#   'close': 2301.4,
#   'volume': 4278479},
#  {'date': datetime.datetime(2023, 2, 21, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2310.55,
#   'high': 2332.3,
#   'low': 2299.45,
#   'close': 2320.2,
#   'volume': 6444922},
#  {'date': datetime.datetime(2023, 2, 22, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2312.4,
#   'high': 2316.3,
#   'low': 2263.9,
#   'close': 2267.55,
#   'volume': 5337526},
#  {'date': datetime.datetime(2023, 2, 23, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2266.7,
#   'high': 2282.7,
#   'low': 2250.85,
#   'close': 2256.7,
#   'volume': 4769887},
#  {'date': datetime.datetime(2023, 2, 24, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2261,
#   'high': 2284,
#   'low': 2257.2,
#   'close': 2272.15,
#   'volume': 4567578},
#  {'date': datetime.datetime(2023, 2, 27, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2270.5,
#   'high': 2277.8,
#   'low': 2241.65,
#   'close': 2257.05,
#   'volume': 5422438},
#  {'date': datetime.datetime(2023, 2, 28, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2245.85,
#   'high': 2256.2,
#   'low': 2205.35,
#   'close': 2213.85,
#   'volume': 10648602},
#  {'date': datetime.datetime(2023, 3, 1, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2234.3,
#   'high': 2235.75,
#   'low': 2214.5,
#   'close': 2234.2,
#   'volume': 5592586},
#  {'date': datetime.datetime(2023, 3, 2, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2227.65,
#   'high': 2241.6,
#   'low': 2212.95,
#   'close': 2217.2,
#   'volume': 4518911},
#  {'date': datetime.datetime(2023, 3, 3, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2239.2,
#   'high': 2281.45,
#   'low': 2231.95,
#   'close': 2273.75,
#   'volume': 7089925},
#  {'date': datetime.datetime(2023, 3, 6, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2287.7,
#   'high': 2311.15,
#   'low': 2287.7,
#   'close': 2295.95,
#   'volume': 4924821},
#  {'date': datetime.datetime(2023, 3, 8, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2295.95,
#   'high': 2305.8,
#   'low': 2273.4,
#   'close': 2304.2,
#   'volume': 7641309},
#  {'date': datetime.datetime(2023, 3, 9, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2302.95,
#   'high': 2303.8,
#   'low': 2244.9,
#   'close': 2248.85,
#   'volume': 7860376},
#  {'date': datetime.datetime(2023, 3, 10, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2231.9,
#   'high': 2234.3,
#   'low': 2206.7,
#   'close': 2214,
#   'volume': 6455814},
#  {'date': datetime.datetime(2023, 3, 13, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2220,
#   'high': 2234.3,
#   'low': 2168.55,
#   'close': 2177.6,
#   'volume': 6183476},
#  {'date': datetime.datetime(2023, 3, 14, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2173.3,
#   'high': 2197.1,
#   'low': 2162.85,
#   'close': 2169.45,
#   'volume': 7759862},
#  {'date': datetime.datetime(2023, 3, 15, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2177.2,
#   'high': 2190.75,
#   'low': 2123.15,
#   'close': 2132.35,
#   'volume': 10520066},
#  {'date': datetime.datetime(2023, 3, 16, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2138.05,
#   'high': 2148.5,
#   'low': 2099.15,
#   'close': 2121.75,
#   'volume': 8890681},
#  {'date': datetime.datetime(2023, 3, 17, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2139.7,
#   'high': 2146.55,
#   'low': 2109.15,
#   'close': 2119.05,
#   'volume': 16468273},
#  {'date': datetime.datetime(2023, 3, 20, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2111.35,
#   'high': 2116.1,
#   'low': 2078,
#   'close': 2098.25,
#   'volume': 9452997},
#  {'date': datetime.datetime(2023, 3, 21, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2115.1,
#   'high': 2167.6,
#   'low': 2113.25,
#   'close': 2163.5,
#   'volume': 10361168},
#  {'date': datetime.datetime(2023, 3, 22, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2178.05,
#   'high': 2184.2,
#   'low': 2163.75,
#   'close': 2170.05,
#   'volume': 5287057},
#  {'date': datetime.datetime(2023, 3, 23, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2161.85,
#   'high': 2163.65,
#   'low': 2138.05,
#   'close': 2142.6,
#   'volume': 7867272},
#  {'date': datetime.datetime(2023, 3, 24, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2140.15,
#   'high': 2144.7,
#   'low': 2095.15,
#   'close': 2100.2,
#   'volume': 5991920},
#  {'date': datetime.datetime(2023, 3, 27, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2113.7,
#   'high': 2148.5,
#   'low': 2097.25,
#   'close': 2132.85,
#   'volume': 6804521},
#  {'date': datetime.datetime(2023, 3, 28, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2139.95,
#   'high': 2150.9,
#   'low': 2132.3,
#   'close': 2142.8,
#   'volume': 6088984},
#  {'date': datetime.datetime(2023, 3, 29, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2134.2,
#   'high': 2139.75,
#   'low': 2107.6,
#   'close': 2130.1,
#   'volume': 9104149},
#  {'date': datetime.datetime(2023, 3, 31, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2149.45,
#   'high': 2233.8,
#   'low': 2149.2,
#   'close': 2221.95,
#   'volume': 13639328},
#  {'date': datetime.datetime(2023, 4, 3, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2235.25,
#   'high': 2239.05,
#   'low': 2206.65,
#   'close': 2222.35,
#   'volume': 4983465},
#  {'date': datetime.datetime(2023, 4, 5, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2238.1,
#   'high': 2238.1,
#   'low': 2200.5,
#   'close': 2217,
#   'volume': 7873836},
#  {'date': datetime.datetime(2023, 4, 6, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2209.65,
#   'high': 2243.85,
#   'low': 2209.65,
#   'close': 2231.85,
#   'volume': 8925486},
#  {'date': datetime.datetime(2023, 4, 10, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2240,
#   'high': 2240.4,
#   'low': 2212.9,
#   'close': 2216.05,
#   'volume': 6275377},
#  {'date': datetime.datetime(2023, 4, 11, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2224.75,
#   'high': 2231.45,
#   'low': 2215.3,
#   'close': 2227,
#   'volume': 5104178},
#  {'date': datetime.datetime(2023, 4, 12, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2227,
#   'high': 2257,
#   'low': 2221,
#   'close': 2236.85,
#   'volume': 8801561},
#  {'date': datetime.datetime(2023, 4, 13, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2242.9,
#   'high': 2255.1,
#   'low': 2232.4,
#   'close': 2245.25,
#   'volume': 5993015},
#  {'date': datetime.datetime(2023, 4, 17, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2311.45,
#   'high': 2311.45,
#   'low': 2239.1,
#   'close': 2256.65,
#   'volume': 8680711},
#  {'date': datetime.datetime(2023, 4, 18, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2265.75,
#   'high': 2265.75,
#   'low': 2217.15,
#   'close': 2230.8,
#   'volume': 5037949},
#  {'date': datetime.datetime(2023, 4, 19, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2229.6,
#   'high': 2247.55,
#   'low': 2223.05,
#   'close': 2241.95,
#   'volume': 5942308},
#  {'date': datetime.datetime(2023, 4, 20, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2243.95,
#   'high': 2248.6,
#   'low': 2222.95,
#   'close': 2236.25,
#   'volume': 3392659},
#  {'date': datetime.datetime(2023, 4, 21, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2240.65,
#   'high': 2250.5,
#   'low': 2227.05,
#   'close': 2239.05,
#   'volume': 3702514},
#  {'date': datetime.datetime(2023, 4, 24, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2263.85,
#   'high': 2269.45,
#   'low': 2238.1,
#   'close': 2247.65,
#   'volume': 6263165},
#  {'date': datetime.datetime(2023, 4, 25, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2255.25,
#   'high': 2269.2,
#   'low': 2240.5,
#   'close': 2264.85,
#   'volume': 4471750},
#  {'date': datetime.datetime(2023, 4, 26, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2267.65,
#   'high': 2274.45,
#   'low': 2243.9,
#   'close': 2251.55,
#   'volume': 4172398},
#  {'date': datetime.datetime(2023, 4, 27, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2263.85,
#   'high': 2272.45,
#   'low': 2253.35,
#   'close': 2265.8,
#   'volume': 4438342},
#  {'date': datetime.datetime(2023, 4, 28, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2270.5,
#   'high': 2310.45,
#   'low': 2270.3,
#   'close': 2307.2,
#   'volume': 7536030},
#  {'date': datetime.datetime(2023, 5, 2, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2322.2,
#   'high': 2331.35,
#   'low': 2314.45,
#   'close': 2326.8,
#   'volume': 6285252},
#  {'date': datetime.datetime(2023, 5, 3, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2330.55,
#   'high': 2330.55,
#   'low': 2300.1,
#   'close': 2306.85,
#   'volume': 3419066},
#  {'date': datetime.datetime(2023, 5, 4, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2307.85,
#   'high': 2338.05,
#   'low': 2301.6,
#   'close': 2333.45,
#   'volume': 4180822},
#  {'date': datetime.datetime(2023, 5, 5, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2326.75,
#   'high': 2346.15,
#   'low': 2322,
#   'close': 2327.5,
#   'volume': 4234734},
#  {'date': datetime.datetime(2023, 5, 8, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2335.35,
#   'high': 2367.4,
#   'low': 2329.75,
#   'close': 2356.2,
#   'volume': 4431882},
#  {'date': datetime.datetime(2023, 5, 9, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2359.15,
#   'high': 2370.4,
#   'low': 2347.95,
#   'close': 2363.5,
#   'volume': 3129950},
#  {'date': datetime.datetime(2023, 5, 10, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2373.45,
#   'high': 2382.85,
#   'low': 2365.1,
#   'close': 2379.75,
#   'volume': 5263895},
#  {'date': datetime.datetime(2023, 5, 11, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2382,
#   'high': 2392.05,
#   'low': 2360.65,
#   'close': 2364.2,
#   'volume': 5111679},
#  {'date': datetime.datetime(2023, 5, 12, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2354.2,
#   'high': 2371,
#   'low': 2341.55,
#   'close': 2368.1,
#   'volume': 3367488},
#  {'date': datetime.datetime(2023, 5, 15, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2373.35,
#   'high': 2387.35,
#   'low': 2357.4,
#   'close': 2372.75,
#   'volume': 3308422},
#  {'date': datetime.datetime(2023, 5, 16, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2377.3,
#   'high': 2382.6,
#   'low': 2335.5,
#   'close': 2338.95,
#   'volume': 4220521},
#  {'date': datetime.datetime(2023, 5, 17, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2347.75,
#   'high': 2349.65,
#   'low': 2315.3,
#   'close': 2325.15,
#   'volume': 4260095},
#  {'date': datetime.datetime(2023, 5, 18, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2334.9,
#   'high': 2342,
#   'low': 2313.55,
#   'close': 2320.15,
#   'volume': 5096026},
#  {'date': datetime.datetime(2023, 5, 19, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2320.15,
#   'high': 2331.5,
#   'low': 2305.65,
#   'close': 2327.65,
#   'volume': 3897693},
#  {'date': datetime.datetime(2023, 5, 22, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2321.05,
#   'high': 2350.6,
#   'low': 2318.5,
#   'close': 2340.1,
#   'volume': 3599673},
#  {'date': datetime.datetime(2023, 5, 23, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2345.5,
#   'high': 2352.5,
#   'low': 2336.7,
#   'close': 2339.7,
#   'volume': 2949511},
#  {'date': datetime.datetime(2023, 5, 24, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2331.45,
#   'high': 2348.7,
#   'low': 2319.55,
#   'close': 2326.05,
#   'volume': 3927617},
#  {'date': datetime.datetime(2023, 5, 25, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2320,
#   'high': 2334.4,
#   'low': 2303,
#   'close': 2325.75,
#   'volume': 5561947},
#  {'date': datetime.datetime(2023, 5, 26, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2342.95,
#   'high': 2391.6,
#   'low': 2336.05,
#   'close': 2389.2,
#   'volume': 6113112},
#  {'date': datetime.datetime(2023, 5, 29, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2403,
#   'high': 2411.6,
#   'low': 2389.85,
#   'close': 2402.65,
#   'volume': 4846575},
#  {'date': datetime.datetime(2023, 5, 30, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2402.65,
#   'high': 2418.95,
#   'low': 2396.7,
#   'close': 2402,
#   'volume': 5491571},
#  {'date': datetime.datetime(2023, 5, 31, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2383,
#   'high': 2392.4,
#   'low': 2345.8,
#   'close': 2354.3,
#   'volume': 13124535},
#  {'date': datetime.datetime(2023, 6, 1, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2364.1,
#   'high': 2368.6,
#   'low': 2342.95,
#   'close': 2347.95,
#   'volume': 7065177},
#  {'date': datetime.datetime(2023, 6, 2, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2355.35,
#   'high': 2366.65,
#   'low': 2336.3,
#   'close': 2340.3,
#   'volume': 7650017},
#  {'date': datetime.datetime(2023, 6, 5, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2351.75,
#   'high': 2367.5,
#   'low': 2343.4,
#   'close': 2361.3,
#   'volume': 5281532},
#  {'date': datetime.datetime(2023, 6, 6, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2367.2,
#   'high': 2371.3,
#   'low': 2346.8,
#   'close': 2363.3,
#   'volume': 3627950},
#  {'date': datetime.datetime(2023, 6, 7, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2370.6,
#   'high': 2383,
#   'low': 2356.9,
#   'close': 2381.25,
#   'volume': 4992907},
#  {'date': datetime.datetime(2023, 6, 8, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2388.7,
#   'high': 2399.05,
#   'low': 2374.4,
#   'close': 2382.65,
#   'volume': 5844331},
#  {'date': datetime.datetime(2023, 6, 9, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2389.65,
#   'high': 2391.15,
#   'low': 2362.05,
#   'close': 2365.8,
#   'volume': 2845409},
#  {'date': datetime.datetime(2023, 6, 12, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2359.65,
#   'high': 2372.7,
#   'low': 2349.65,
#   'close': 2367.9,
#   'volume': 3094727},
#  {'date': datetime.datetime(2023, 6, 13, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2378.25,
#   'high': 2405.35,
#   'low': 2369.9,
#   'close': 2402.85,
#   'volume': 5445824},
#  {'date': datetime.datetime(2023, 6, 14, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2403,
#   'high': 2435.45,
#   'low': 2399.2,
#   'close': 2432.4,
#   'volume': 6428357},
#  {'date': datetime.datetime(2023, 6, 15, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2432.4,
#   'high': 2442.6,
#   'low': 2416.85,
#   'close': 2433.1,
#   'volume': 5719605},
#  {'date': datetime.datetime(2023, 6, 16, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2440.4,
#   'high': 2461.55,
#   'low': 2440.4,
#   'close': 2456.8,
#   'volume': 11702877},
#  {'date': datetime.datetime(2023, 6, 19, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2463.05,
#   'high': 2463.05,
#   'low': 2423.65,
#   'close': 2432.4,
#   'volume': 3291579},
#  {'date': datetime.datetime(2023, 6, 20, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2428.3,
#   'high': 2444,
#   'low': 2416.35,
#   'close': 2437.45,
#   'volume': 3350908},
#  {'date': datetime.datetime(2023, 6, 21, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2437.35,
#   'high': 2449.6,
#   'low': 2428.75,
#   'close': 2444.3,
#   'volume': 3370520},
#  {'date': datetime.datetime(2023, 6, 22, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2436.4,
#   'high': 2452.85,
#   'low': 2413.5,
#   'close': 2416.85,
#   'volume': 3688885},
#  {'date': datetime.datetime(2023, 6, 23, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2410.55,
#   'high': 2414.85,
#   'low': 2394.45,
#   'close': 2397.05,
#   'volume': 3209279},
#  {'date': datetime.datetime(2023, 6, 26, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2389.65,
#   'high': 2397.7,
#   'low': 2372.25,
#   'close': 2378.75,
#   'volume': 6120325},
#  {'date': datetime.datetime(2023, 6, 27, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2379.7,
#   'high': 2392.05,
#   'low': 2370.25,
#   'close': 2379.6,
#   'volume': 4691238},
#  {'date': datetime.datetime(2023, 6, 28, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2395.4,
#   'high': 2419.1,
#   'low': 2380.95,
#   'close': 2411.1,
#   'volume': 5497139},
#  {'date': datetime.datetime(2023, 6, 30, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2427.25,
#   'high': 2437,
#   'low': 2414.9,
#   'close': 2430.9,
#   'volume': 5399121},
#  {'date': datetime.datetime(2023, 7, 3, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2438.35,
#   'high': 2499.3,
#   'low': 2435.75,
#   'close': 2493.3,
#   'volume': 5884651},
#  {'date': datetime.datetime(2023, 7, 4, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2502.15,
#   'high': 2502.15,
#   'low': 2452.8,
#   'close': 2467.6,
#   'volume': 3903114},
#  {'date': datetime.datetime(2023, 7, 5, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2486.9,
#   'high': 2486.9,
#   'low': 2455.25,
#   'close': 2463.55,
#   'volume': 4961687},
#  {'date': datetime.datetime(2023, 7, 6, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2455.5,
#   'high': 2520.7,
#   'low': 2455.5,
#   'close': 2515.25,
#   'volume': 9256137},
#  {'date': datetime.datetime(2023, 7, 7, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2511.7,
#   'high': 2540.25,
#   'low': 2505,
#   'close': 2510.35,
#   'volume': 6475750},
#  {'date': datetime.datetime(2023, 7, 10, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2563.05,
#   'high': 2627,
#   'low': 2549.8,
#   'close': 2607.05,
#   'volume': 16093438},
#  {'date': datetime.datetime(2023, 7, 11, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2624.05,
#   'high': 2640.35,
#   'low': 2609.5,
#   'close': 2635.3,
#   'volume': 9716747},
#  {'date': datetime.datetime(2023, 7, 12, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2636.85,
#   'high': 2670.85,
#   'low': 2632.4,
#   'close': 2638.2,
#   'volume': 9070147},
#  {'date': datetime.datetime(2023, 7, 13, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2653.6,
#   'high': 2668,
#   'low': 2609.15,
#   'close': 2614.65,
#   'volume': 7108868},
#  {'date': datetime.datetime(2023, 7, 14, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2621.3,
#   'high': 2631.7,
#   'low': 2597.55,
#   'close': 2612.45,
#   'volume': 7322484},
#  {'date': datetime.datetime(2023, 7, 17, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2618.45,
#   'high': 2683.3,
#   'low': 2600.35,
#   'close': 2665.8,
#   'volume': 10758023},
#  {'date': datetime.datetime(2023, 7, 18, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2685.15,
#   'high': 2704.65,
#   'low': 2662.3,
#   'close': 2688.45,
#   'volume': 12523881},
#  {'date': datetime.datetime(2023, 7, 19, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2697.55,
#   'high': 2722.35,
#   'low': 2666.1,
#   'close': 2708.85,
#   'volume': 18941327},
#  {'date': datetime.datetime(2023, 7, 20, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2580,
#   'high': 2630.95,
#   'low': 2580,
#   'close': 2619.85,
#   'volume': 19358812},
#  {'date': datetime.datetime(2023, 7, 21, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2609,
#   'high': 2614.9,
#   'low': 2523.6,
#   'close': 2538.75,
#   'volume': 15124619},
#  {'date': datetime.datetime(2023, 7, 24, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2481,
#   'high': 2514.95,
#   'low': 2469.3,
#   'close': 2487.4,
#   'volume': 11863933},
#  {'date': datetime.datetime(2023, 7, 25, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2494,
#   'high': 2505.2,
#   'low': 2480,
#   'close': 2485.8,
#   'volume': 6013010},
#  {'date': datetime.datetime(2023, 7, 26, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2485,
#   'high': 2547,
#   'low': 2485,
#   'close': 2526.2,
#   'volume': 6455506},
#  {'date': datetime.datetime(2023, 7, 27, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2534.05,
#   'high': 2537.65,
#   'low': 2490.35,
#   'close': 2502.7,
#   'volume': 8613449},
#  {'date': datetime.datetime(2023, 7, 28, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2512.05,
#   'high': 2542.85,
#   'low': 2500.55,
#   'close': 2527.85,
#   'volume': 10413926},
#  {'date': datetime.datetime(2023, 7, 31, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2527.85,
#   'high': 2553.9,
#   'low': 2517.95,
#   'close': 2549.25,
#   'volume': 4275587},
#  {'date': datetime.datetime(2023, 8, 1, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2555,
#   'high': 2559,
#   'low': 2505.3,
#   'close': 2513.2,
#   'volume': 4768316},
#  {'date': datetime.datetime(2023, 8, 2, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2509.2,
#   'high': 2512,
#   'low': 2463.6,
#   'close': 2486.35,
#   'volume': 6374107},
#  {'date': datetime.datetime(2023, 8, 3, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2475.3,
#   'high': 2500.9,
#   'low': 2458.05,
#   'close': 2475.9,
#   'volume': 5084175},
#  {'date': datetime.datetime(2023, 8, 4, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2498.8,
#   'high': 2516,
#   'low': 2471.6,
#   'close': 2509.55,
#   'volume': 11442805},
#  {'date': datetime.datetime(2023, 8, 7, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2521,
#   'high': 2528.4,
#   'low': 2505,
#   'close': 2523.85,
#   'volume': 2991435},
#  {'date': datetime.datetime(2023, 8, 8, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2528,
#   'high': 2534.45,
#   'low': 2499.55,
#   'close': 2508.65,
#   'volume': 4922036},
#  {'date': datetime.datetime(2023, 8, 9, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2504.85,
#   'high': 2529,
#   'low': 2481.1,
#   'close': 2525.2,
#   'volume': 5743293},
#  {'date': datetime.datetime(2023, 8, 10, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2524.95,
#   'high': 2550,
#   'low': 2508.45,
#   'close': 2536.45,
#   'volume': 7735299},
#  {'date': datetime.datetime(2023, 8, 11, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2532.45,
#   'high': 2558.85,
#   'low': 2512.35,
#   'close': 2547.15,
#   'volume': 11089665},
#  {'date': datetime.datetime(2023, 8, 14, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2539,
#   'high': 2582.3,
#   'low': 2525,
#   'close': 2577.25,
#   'volume': 4787906},
#  {'date': datetime.datetime(2023, 8, 16, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2551,
#   'high': 2582.8,
#   'low': 2551,
#   'close': 2575.15,
#   'volume': 5101556},
#  {'date': datetime.datetime(2023, 8, 17, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2567.1,
#   'high': 2578.1,
#   'low': 2532.85,
#   'close': 2538,
#   'volume': 6836872},
#  {'date': datetime.datetime(2023, 8, 18, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2531.25,
#   'high': 2577.6,
#   'low': 2508.55,
#   'close': 2556.8,
#   'volume': 9319989},
#  {'date': datetime.datetime(2023, 8, 21, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2539.95,
#   'high': 2555.45,
#   'low': 2515.65,
#   'close': 2520,
#   'volume': 4610873},
#  {'date': datetime.datetime(2023, 8, 22, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2516.9,
#   'high': 2537.95,
#   'low': 2499,
#   'close': 2519.4,
#   'volume': 3856522},
#  {'date': datetime.datetime(2023, 8, 23, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2524.2,
#   'high': 2542.85,
#   'low': 2516.95,
#   'close': 2522.2,
#   'volume': 4758976},
#  {'date': datetime.datetime(2023, 8, 24, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2539.9,
#   'high': 2539.9,
#   'low': 2471,
#   'close': 2479.8,
#   'volume': 7070010},
#  {'date': datetime.datetime(2023, 8, 25, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2456,
#   'high': 2505,
#   'low': 2442.6,
#   'close': 2468.35,
#   'volume': 11111200},
#  {'date': datetime.datetime(2023, 8, 28, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2472,
#   'high': 2484,
#   'low': 2431.1,
#   'close': 2443.75,
#   'volume': 6290413},
#  {'date': datetime.datetime(2023, 8, 29, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2452.05,
#   'high': 2453.45,
#   'low': 2408.15,
#   'close': 2420.35,
#   'volume': 8438322},
#  {'date': datetime.datetime(2023, 8, 30, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2432,
#   'high': 2443,
#   'low': 2415,
#   'close': 2418.05,
#   'volume': 6084473},
#  {'date': datetime.datetime(2023, 8, 31, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2423,
#   'high': 2425,
#   'low': 2399.9,
#   'close': 2407,
#   'volume': 10819300},
#  {'date': datetime.datetime(2023, 9, 1, 0, 0, tzinfo=tzoffset(None, 19800)),
#   'open': 2406.55,
#   'high': 2425.65,
#   'low': 2401.65,
#   'close': 2412.65,
#   'volume': 9056421}]
